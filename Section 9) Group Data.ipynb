# %%
import pandas as pd

# %%
adf =pd.DataFrame({"x1": ["A","B","C"], "x2":[1,2,3] })
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf =  pd.DataFrame({"x1":["A","B","D"], "x3" : ["T","F","T"]})
bdf
# Out:
#   x1 x3
# 0  A  T
# 1  B  F
# 2  D  T

# %%
pd.merge(adf, bdf, how ='left', on = 'x1')#기준: left, 키는 x1
# Out:
#   x1  x2   x3
# 0  A   1    T
# 1  B   2    F
# 2  C   3  NaN

# %%
pd.merge(adf, bdf, how = 'right', on = 'x1')
# Out:
#   x1   x2 x3
# 0  A  1.0  T
# 1  B  2.0  F
# 2  D  NaN  T

# %%
pd.merge(adf,bdf,how='inner',on = 'x1')
# Out:
#   x1  x2 x3
# 0  A   1  T
# 1  B   2  F

# %%
pd.merge(adf,bdf,how='outer',on = 'x1')
# Out:
#   x1   x2   x3
# 0  A  1.0    T
# 1  B  2.0    F
# 2  C  3.0  NaN
# 3  D  NaN    T

# %%
bdf.x1
# Out:
# 0    A
# 1    B
# 2    D
# Name: x1, dtype: object

# %%
adf[adf.x1.isin(bdf.x1)]#bdf의 x1에 있는 값이 adf의 x1에도 있으면 (교집합)출력
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
adf[~adf.x1.isin(bdf.x1)]#bdf.x1와 adf.x1의 교집합이 아닌 요소출력
# Out:
#   x1  x2
# 2  C   3

# %%
ydf = pd.DataFrame({"x1" : ["A", "B", "C"], "x2" : [1,2,3]})
ydf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
zdf = pd.DataFrame({"x1" : ["B", "C", "D"], "x2" : [2,3,4]})
zdf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(ydf,zdf)#디폴트 : inner조인
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
pd.merge(ydf, zdf, how='outer')
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
pd.merge(ydf, zdf, how = 'outer', indicator = True)
# Out:
#   x1  x2      _merge
# 0  A   1   left_only
# 1  B   2        both
# 2  C   3        both
# 3  D   4  right_only

# %%
#쿼리 문을 이용해서 left_only인 indicator를 가지는 값만 가져오고 _merge컬럼은 drop
pd.merge(ydf, zdf, how = 'outer', indicator = True).query('_merge=="left_only"').drop(columns=['_merge'])
# Out:
#   x1  x2
# 0  A   1

# %% [markdown]
# -------------------------
# concat : 위아래로 합칠때
# merge : 옆으로 합칠때

# %% [markdown]
# -------------------------------
# group화 하기

# %%
import seaborn as sns

# %%
df = sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
df.groupby(by = "origin").size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# dtype: int64

# %%
df.origin.value_counts()#groupby().size()와 똑같
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
#각 origin의 cylinders의 중간값
df.groupby(by = "origin")['cylinders'].median()
# Out:
# origin
# europe    4
# japan     4
# usa       6
# Name: cylinders, dtype: int64

# %%
pd.DataFrame(df.groupby(['model_year', 'origin'])['cylinders'].mean()).head()
# Out:
#                    cylinders
# model_year origin
# 70         europe   4.000000
#            japan    4.000000
#            usa      7.636364
# 71         europe   4.000000
#            japan    4.000000

# %%
df2 = pd.DataFrame([[5,3,2],[3,2,6],[23,12,63]], index = [1,2,3],columns = ['a','b','c'])

# %%
df2
# Out:
#     a   b   c
# 1   5   3   2
# 2   3   2   6
# 3  23  12  63

# %%
df2.shift(1)
# Out:
#      a    b    c
# 1  NaN  NaN  NaN
# 2  5.0  3.0  2.0
# 3  3.0  2.0  6.0

# %%
df2.shift(-1)
# Out:
#       a     b     c
# 1   3.0   2.0   6.0
# 2  23.0  12.0  63.0
# 3   NaN   NaN   NaN

# %%
pd.DataFrame(df2.a.shift(2))#결측치 채울때 유용
# Out:
#      a
# 1  NaN
# 2  NaN
# 3  5.0

# %%
df2['new'] = [1,2,3]
df2 = df2.drop(columns = 'new')

# %%
df2.shift(-1)
# Out:
#       a     b     c
# 1   3.0   2.0   6.0
# 2  23.0  12.0  63.0
# 3   NaN   NaN   NaN

# %% [markdown]
# -----------------------------
# 새로운 컬럼or로우 만들고 shift를 수행하면 결측치 채움

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
#model_year컬럼의 값의 최소값을 순위를 매겨서 각 순위를 count하라
df.model_year.rank(method='min').value_counts()
# Out:
# 86.0     40
# 245.0    36
# 183.0    34
# 368.0    31
# 153.0    30
# 339.0    29
# 281.0    29
# 310.0    29
# 1.0      29
# 217.0    28
# 58.0     28
# 30.0     28
# 126.0    27
# Name: model_year, dtype: int64

# %%
#비율이 어느정도? -> pct
df.model_year.rank(pct = True)
# Out:
# 0      0.037688
# 1      0.037688
# 2      0.037688
# 3      0.037688
# 4      0.037688
# 5      0.037688
# 6      0.037688
# 7      0.037688
# 8      0.037688
# 9      0.037688
# 10     0.037688
# 11     0.037688
# 12     0.037688
# 13     0.037688
# 14     0.037688
# 15     0.037688
# 16     0.037688
# 17     0.037688
# 18     0.037688
# 19     0.037688
# 20     0.037688
# 21     0.037688
# 22     0.037688
# 23     0.037688
# 24     0.037688
# 25     0.037688
# 26     0.037688
# 27     0.037688
# 28     0.037688
# 29     0.109296
#          ...
# 368    0.962312
# 369    0.962312
# 370    0.962312
# 371    0.962312
# 372    0.962312
# 373    0.962312
# 374    0.962312
# 375    0.962312
# 376    0.962312
# 377    0.962312
# 378    0.962312
# 379    0.962312
# 380    0.962312
# 381    0.962312
# 382    0.962312
# 383    0.962312
# 384    0.962312
# 385    0.962312
# 386    0.962312
# 387    0.962312
# 388    0.962312
# 389    0.962312
# 390    0.962312
# 391    0.962312
# ...

# %%
df.model_year.rank(method = 'first')#값이 같아도 순위 중복 X
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
# 5        6.0
# 6        7.0
# 7        8.0
# 8        9.0
# 9       10.0
# 10      11.0
# 11      12.0
# 12      13.0
# 13      14.0
# 14      15.0
# 15      16.0
# 16      17.0
# 17      18.0
# 18      19.0
# 19      20.0
# 20      21.0
# 21      22.0
# 22      23.0
# 23      24.0
# 24      25.0
# 25      26.0
# 26      27.0
# 27      28.0
# 28      29.0
# 29      30.0
#        ...
# 368    369.0
# 369    370.0
# 370    371.0
# 371    372.0
# 372    373.0
# 373    374.0
# 374    375.0
# 375    376.0
# 376    377.0
# 377    378.0
# 378    379.0
# 379    380.0
# 380    381.0
# 381    382.0
# 382    383.0
# 383    384.0
# 384    385.0
# 385    386.0
# 386    387.0
# 387    388.0
# 388    389.0
# 389    390.0
# 390    391.0
# 391    392.0
# 392    393.0
# 393    394.0
# 394    395.0
# 395    396.0
# 396    397.0
# 397    398.0
# Name: model_year, Length: 398, dtype: float64

# %%
df2
# Out:
#     a   b   c
# 1   5   3   2
# 2   3   2   6
# 3  23  12  63

# %%
df2.cumsum()#row(n) += row(n-1)
# Out:
#     a   b   c
# 1   5   3   2
# 2   8   5   8
# 3  31  17  71

# %%
df2.cummin()
#한 행씩 내려가면서 최솟값을 찾으면 그것만 나오도록
# Out:
#    a  b  c
# 1  5  3  2
# 2  3  2  2
# 3  3  2  2

# %%
df2.cumprod()
#row(n)  *= row(n-1)
# Out:
#      a   b    c
# 1    5   3    2
# 2   15   6   12
# 3  345  72  756
